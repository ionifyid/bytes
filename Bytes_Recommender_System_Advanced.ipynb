# %% [markdown]
# <a href="https://colab.research.google.com/github/gemm123/bytes/blob/machine-learning/Bytes_Recommender_System_Advanced.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import necessary library

# %%
import pandas as pd
import numpy as np
import json
import random

# !pip install Sastrawi
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import nltk
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from sklearn.feature_extraction.text import TfidfVectorizer

# !pip install surprise
from surprise import SVD
from surprise import Dataset
from surprise import Reader
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# Data yang dikirim Backend

# %%
#@title
true = True
false = False

json_data = {
  "data": [
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "d802cc81-fa37-4463-80a6-119f9767a308",
      "UserLikeCourse": true,
      "Title": "Data Classes dan Collections",
      "Description": "Fokus pada bagaimana mengelola data di Kotlin dengan menggunakan data class dan collection. Anda juga akan belajar mengenai perbedaan antara collection yang ada pada Kotlin dan menggunakannya.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Data Classes adalah class yang secara otomatis menyediakan fungsi utama seperti toString(), equals(), hashCode(), dan copy() yang digunakan untuk memudahkan pengolahan data.;Collections adalah kumpulan objek dalam satu tempat yang dapat diakses dan dimanipulasi dalam berbagai cara, seperti menambah atau menghapus elemen, mengurutkan, dan memfilter.;Kotlin menyediakan beberapa jenis collections seperti List, Set, dan Map dengan fitur-fitur khusus seperti immutable dan mutable collections."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "4ff43f8a-e086-45c2-ae8e-141cf399a3f6",
      "UserLikeCourse": false,
      "Title": "Kotlin Functional Programming",
      "Description": "Memahami konsep function programing dengan mempelajari extension, lambda, higher-order function, recursion serta melihat contoh penerapannya pada collection operator dan scope function.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Kotlin mendukung paradigma functional programming, yaitu gaya pemrograman yang fokus pada penggunaan fungsi sebagai objek utama untuk membuat program.;Beberapa fitur fungsional di Kotlin antara lain higher-order functions, lambda expressions, dan operator overloading.;Fungsional programming memudahkan pengembangan aplikasi yang bersifat deklaratif dan meminimalkan penggunaan mutable state."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "de28628f-4a54-4b86-ba62-c5ca5ec1c519",
      "UserLikeCourse": true,
      "Title": "Kotlin Object-Oriented Programming",
      "Description": "Memahami mengenai konsep OOP pada Kotlin, bagaimana membuat sebuah class, properti dan fungsi dari class, dan menyimulasikan problematika dunia nyata dalam paradigma object-oriented programming (OOP). Memahami konsep OOP dengan mempelajari inheritance, abstract class, interface, visibility modifier, dan overloading.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Kotlin adalah bahasa pemrograman berorientasi objek (object-oriented programming) yang menyediakan fitur-fitur seperti inheritance, encapsulation, dan polymorphism.;Dalam Kotlin, semua tipe data adalah objek, termasuk tipe primitif seperti Int dan Boolean.;Kotlin juga menyediakan beberapa fitur objek khusus seperti companion object dan object expressions."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "d6cedcea-d9e2-44e5-9377-d6bb270e5f78",
      "UserLikeCourse": false,
      "Title": "Kotlin Generics",
      "Description": "Belajar tentang variance dan cara menggunakan generic untuk membuat kelas yang dapat menerima berbagai jenis tipe data.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Generics adalah fitur yang memungkinkan tipe data menjadi parameter dalam class atau fungsi.;Kotlin menyediakan generics yang mendukung variance, yaitu kemampuan untuk mengkonversi tipe data yang memiliki hierarki yang sama, seperti subkelas dan superkelas.;Contoh generics di Kotlin antara lain List<T>, Set<T>, dan Map<K, V>."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "2b248422-5313-4d40-bde6-3b32b3c9ac52",
      "UserLikeCourse": false,
      "Title": "Berkenalan dengan Coroutines",
      "Description": "Belajar dasar dari konsep concurrency seperti process dan thread. Anda juga akan diajarkan tentang permasalahan dalam proses yang bersamaan seperti deadlock, livelock, starvation, dan race condition. Dengan memahami permasalahan tersebut, Anda akan belajar menggunakan Coroutine dalam menyelesaikannya.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Coroutines adalah fitur pada Kotlin untuk melakukan tugas secara asynchronous dan non-blocking.;Coroutines memungkinkan kode dapat dijalankan secara sekuensial tanpa memblokir thread utama, sehingga meningkatkan efisiensi dan responsivitas aplikasi.;Coroutines menggunakan konsep suspend function dan job untuk mengatur urutan tugas."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "991c7694-ec46-450d-abc1-b47ab1bb6e41",
      "UserLikeCourse": false,
      "Title": "Dasar Pengembangan Aplikasi Android",
      "Description": "Memahami konsep dasar mengembangkan aplikasi Android dengan menggunakan Activity, Intent, Fragment, View & View Group, dan Style & Theme.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Pengembangan aplikasi Android membutuhkan pemahaman tentang komponen-komponen dasar seperti Activity, Fragment, Service, dan BroadcastReceiver.;Android Studio adalah IDE yang digunakan untuk mengembangkan aplikasi Android dengan bahasa pemrograman Kotlin atau Java.;Aplikasi Android memiliki siklus hidup (lifecycle) yang perlu dipahami untuk mengelola state dan menjaga performa aplikasi."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "e9fdbf92-8901-4d3d-984f-31aa639efce8",
      "UserLikeCourse": true,
      "Title": "Fragment",
      "Description": "Mengetahui konsep Fragment untuk membuat tampilan yang modular dan fleksibel.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Fragment adalah komponen UI pada Android yang dapat digunakan untuk memecah tampilan menjadi bagian yang lebih kecil dan dapat di-reuse pada beberapa Activity.;Fragment memiliki siklus hidup yang mirip dengan Activity dan dapat dikontrol oleh Activity yang menggunakannya.;Fragment dapat diubah, ditambah, atau dihapus secara dinamis pada saat runtime."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "63fc4048-ea01-47ce-aefb-7793d6d53915",
      "UserLikeCourse": false,
      "Title": "Navigation",
      "Description": "Mengetahui cara menggunakan berbagai macam komponen navigasi, seperti Navigation Component, Option Menu pada Action Bar, Navigation Drawer, Bottom Navigation, dan Tab Layout dengan ViewPager2",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Navigation adalah fitur pada Android yang digunakan untuk mengatur navigasi antara komponen UI seperti Activity dan Fragment dalam aplikasi.;Navigation menyediakan komponen Navigation Graph untuk memvisualisasikan dan mengatur hubungan antara komponen UI.;Navigation juga menyediakan fitur animasi transisi dan argument passing antar komponen UI."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "edb5749d-ed25-4929-a524-51dac04e2e52",
      "UserLikeCourse": false,
      "Title": "Background Thread dan Networking",
      "Description": "Mendalami cara mengeksekusi proses secara asynchronous di background thread supaya tidak terjadi freeze serta memahami cara mengambil data dari Web API yang berformat JSON dan mem-parsing-nya.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Background thread adalah thread yang berjalan di luar thread utama aplikasi untuk melakukan tugas yang membutuhkan waktu lama atau memakan sumber daya yang besar, seperti networking atau pengolahan data.;Kotlin menyediakan beberapa cara untuk membuat background thread, seperti menggunakan fungsi async dan await, atau menggunakan coroutines.;Networking adalah proses mengambil data dari internet atau memperbarui data ke internet. Kotlin menyediakan library khusus untuk melakukan networking seperti Retrofit atau Volley."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "5564e197-d473-48f3-a9a2-560f07029de1",
      "UserLikeCourse": false,
      "Title": "Android Architecture Component",
      "Description": "Mengetahui architecture pattern yang direkomendasikan Google untuk membuat kode yang mudah dibaca dan dipelihara, yakni dengan menggunakan ViewModel dan LiveData.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Android Architecture Component adalah library yang disediakan oleh Google untuk memudahkan pengembangan aplikasi Android dengan arsitektur yang terstruktur.;Android Architecture Component terdiri dari beberapa komponen, seperti Room untuk database, ViewModel dan LiveData untuk mengatur data, dan Navigation untuk mengatur navigasi.;Android Architecture Component memudahkan pengembangan aplikasi yang mudah dipelihara, mudah diuji, dan skalabilitas yang baik."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "1cbfd3c5-201d-409f-a827-1de66758e713",
      "UserLikeCourse": false,
      "Title": "Studi Kasus Implementasi Navigation dan API",
      "Description": "Menguji pemahaman siswa dalam implementasi pengetahuan dengan cara membuat aplikasi yang dapat melakukan pencarian data dari Web API dan membuat menu navigasi yang sesuai dengan Material Design.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Implementasi Navigation dan API dapat dilakukan dalam pengembangan aplikasi Android untuk menghubungkan antara komponen UI dan data dari API.;Contoh studi kasus adalah membuat aplikasi katalog produk yang menampilkan daftar produk dari API dan menghubungkannya dengan halaman detail produk menggunakan Navigation Component.;Studi kasus ini melibatkan penggunaan Retrofit untuk melakukan HTTP request ke API dan menyimpan data ke dalam ViewModel untuk diakses oleh komponen UI."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "c4820218-9157-4422-9041-69edc145d6cc",
      "UserLikeCourse": false,
      "Title": "Testing",
      "Description": "Memahami cara untuk menguji aplikasi secara otomatis dengan melakukan Unit Testing dan Instrumentation Testing.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Testing adalah proses memeriksa kode untuk memastikan aplikasi berfungsi sesuai dengan yang diharapkan.;Kotlin menyediakan beberapa jenis tes, seperti unit testing untuk menguji fungsi atau class secara terisolasi, dan UI testing untuk menguji tampilan dan interaksi pengguna pada aplikasi.;Android Studio menyediakan fitur untuk membuat dan menjalankan tes, seperti Android Test dan Espresso."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "416e0433-dbae-4c49-b559-2acbe0de3066",
      "UserLikeCourse": true,
      "Title": "Local Data Persistent",
      "Description": "Menjelaskan macam-macam cara untuk menyimpan data di Android seperti File Storage, DataStore, dan database Room.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Local data persistent adalah proses menyimpan data ke dalam penyimpanan lokal, seperti database atau file, untuk diakses kembali di masa depan.;Kotlin menyediakan beberapa library untuk melakukan local data persistent, seperti Room untuk database, atau SharedPreferences untuk menyimpan data kecil dalam format key-value.;Local data persistent dapat digunakan untuk menyimpan data yang diambil dari API atau data pengguna yang tidak perlu disimpan di server."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "286286a3-1380-414a-b0ec-a607be4af4a0",
      "UserLikeCourse": false,
      "Title": "Background Task & Scheduler",
      "Description": "Menjelaskan berbagai cara untuk menjalankan task di background dan beberapa komponen untuk Scheduler seperti AlarmManager dan WorkManager.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Background task dan scheduler digunakan untuk menjalankan tugas di background pada waktu tertentu atau dengan jadwal yang telah ditentukan.;Kotlin menyediakan beberapa cara untuk membuat background task, seperti menggunakan WorkManager atau AlarmManager.;Background task dan scheduler dapat digunakan untuk melakukan tugas periodik, seperti sinkronisasi data, atau tugas yang membutuhkan waktu lama dan tidak perlu dijalankan saat aplikasi sedang aktif."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "952f6af5-a21f-4ec5-b213-21485b11b644",
      "UserLikeCourse": false,
      "Title": "Pengenalan Android Studio",
      "Description": "Memahami penggunaan Android Studio untuk membuat dan menjalankan project serta mengekspornya menjadi APK/AAB.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Android Studio adalah Integrated Development Environment (IDE) yang digunakan untuk mengembangkan aplikasi Android.;Android Studio menyediakan fitur-fitur seperti code editor, debugger, emulator, dan plugin untuk memudahkan pengembangan aplikasi.;Android Studio juga mendukung pengembangan aplikasi dengan bahasa pemrograman Kotlin dan Java."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "7bca9ef0-90a1-4c18-a043-6001dca35b8a",
      "UserLikeCourse": false,
      "Title": "Activity",
      "Description": "Mempelajari konsep dasar Activity dan lifecycle-nya untuk mengambil dan menampilkan data.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Activity adalah komponen dasar pada Android yang merepresentasikan satu layar atau halaman pada aplikasi.;Activity memiliki siklus hidup (lifecycle) yang perlu dipahami untuk mengelola state dan menjaga keberlangsungan aplikasi, seperti onCreate(), onStart(), onResume(), onPause(), onStop(), dan onDestroy().;Activity dapat menerima input dari pengguna melalui interaksi dengan UI, seperti tombol atau input teks, dan dapat berinteraksi dengan komponen lain dalam aplikasi, seperti fragment atau service."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "00bd63dd-6995-477a-9ecd-ec35bef79759",
      "UserLikeCourse": false,
      "Title": "Intent",
      "Description": "Memahami cara untuk berpindah halaman beserta mengirimkan data pada aplikasi, baik dengan Explicit Intent maupun Implicit Intent.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Intent adalah objek yang digunakan untuk menghubungkan antara komponen pada aplikasi Android, seperti activity atau service, atau dengan komponen di aplikasi lain.;Intent digunakan untuk mengirim pesan antar komponen, seperti memulai activity baru atau memulai service untuk menjalankan tugas di background.;Intent dapat mengirim data bersamaan dengan pesan, seperti data teks atau gambar, yang dapat diakses oleh komponen penerima."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "c558fac6-a35f-4f8e-a6cc-314706126e5f",
      "UserLikeCourse": false,
      "Title": "View dan ViewGroup",
      "Description": "Mengetahui berbagai macam layout dan komponen yang dapat digunakan untuk mendesain aplikasi.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "View dan ViewGroup adalah komponen UI dasar pada Android untuk menampilkan tampilan aplikasi.;View adalah komponen dasar yang digunakan untuk menampilkan elemen UI, seperti tombol atau teks.;ViewGroup adalah komponen yang digunakan untuk mengelompokkan beberapa view menjadi satu tampilan, seperti LinearLayout atau RelativeLayout"
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "e9265e58-d9e8-4f62-9b1a-27d765d79fe2",
      "UserLikeCourse": false,
      "Title": "Style dan Theme",
      "Description": "Memahami implementasi style & theme untuk mempersingkat pembuatan desain aplikasi.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Style dan Theme digunakan untuk menyediakan tampilan dan gaya yang konsisten pada aplikasi Android.;Style adalah kumpulan atribut tampilan yang dapat diterapkan pada komponen UI, seperti teks atau background.;Theme adalah kumpulan style yang digunakan untuk menerapkan tampilan dan gaya pada seluruh aplikasi atau pada activity tertentu."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "1c8e0c97-5771-474b-a452-4863227dd764",
      "UserLikeCourse": false,
      "Title": "RecyclerView",
      "Description": "Memahami konsep dan cara kerja RecyclerView untuk menampilkan data yang berjumlah banyak secara dinamis dan contoh penggunaan Layout Manager.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "RecyclerView adalah komponen UI yang digunakan untuk menampilkan daftar item yang banyak pada aplikasi Android.;RecyclerView menggunakan konsep ViewHolder untuk mempercepat tampilan daftar dengan menghindari pembuatan ulang tampilan setiap kali daftar diperbarui.;RecyclerView dapat disesuaikan dengan menggunakan adapter untuk mengatur data dan menggunakan layout manager untuk mengatur tampilan item dalam daftar."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "736bbd9d-4894-423e-97f0-ec844dd96e87",
      "UserLikeCourse": false,
      "Title": "Advanced UI",
      "Description": "Memahami bagaimana meningkatkan pengalaman pengguna dengan menggunakan Custom View, Widget, dan WebView.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Advanced UI adalah teknik pengembangan UI yang lebih kompleks dan canggih pada aplikasi Android, seperti penggunaan custom view atau penggunaan OpenGL.;Advanced UI dapat memberikan tampilan yang lebih menarik dan interaktif pada aplikasi, seperti animasi yang kompleks atau efek 3D.;Advanced UI memerlukan pengetahuan yang lebih mendalam pada teknologi pengembangan Android dan bahasa pemrograman Kotlin atau Java."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "c76be580-dbd4-4a8d-b7c6-c0d0ae98b875",
      "UserLikeCourse": false,
      "Title": "Animation",
      "Description": "Memahami bagaimana cara membuat animasi, baik menggunakan Properti Animation maupun Motion Layout.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Animation digunakan untuk memberikan efek visual pada aplikasi Android, seperti transisi antar layar atau pergerakan elemen UI.;Android menyediakan beberapa jenis animasi, seperti tween animation atau property animation, yang dapat disesuaikan dengan menggunakan XML atau kode Kotlin.;Animasi dapat meningkatkan pengalaman pengguna pada aplikasi dengan memberikan feedback pada interaksi pengguna atau meningkatkan kesan estetik pada tampilan aplikasi."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "a3213180-2cf6-45a5-bb5b-d28275eface2",
      "UserLikeCourse": false,
      "Title": "Localization & Accessibility",
      "Description": "Memahami bagaimana menjangkau lebih banyak pengguna dengan menerapkan Localization untuk mendukung multi-bahasa dan Accessibility untuk mendukung pengguna berkebutuhan khusus.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Localization digunakan untuk mengubah tampilan aplikasi ke dalam berbagai bahasa dan lokalisasi pada aplikasi Android.;Accessibility digunakan untuk membuat aplikasi dapat diakses oleh pengguna dengan berbagai kebutuhan khusus, seperti pengguna dengan gangguan penglihatan atau pendengaran.;Android menyediakan beberapa fitur untuk localization dan accessibility, seperti string resources dan content descriptions, yang dapat disesuaikan pada XML atau kode Kotlin."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "2aefef1c-7c8e-4743-945c-c4b06cf28dba",
      "UserLikeCourse": true,
      "Title": "Service",
      "Description": "Memahami bagaimana Service berjalan untuk melakukan suatu aksi di Background Thread.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Service adalah komponen pada aplikasi Android yang berjalan di background untuk menjalankan tugas yang memakan waktu lama atau berulang, seperti mengambil data dari internet atau memutar musik.;Service dapat dijalankan secara terpisah dari activity atau service lain, atau dapat dijalankan bersama dengan activity yang terkait.;Service dapat berjalan dalam dua mode, yaitu start mode dan bound mode."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "9387ad70-476f-43f1-8603-832bf1eb9744",
      "UserLikeCourse": false,
      "Title": "Media",
      "Description": "Memahami cara mengelola media, baik berupa audio, video, maupun gambar dan mengunggahnya ke server dengan menggunakan Multipart.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Media adalah komponen pada aplikasi Android yang digunakan untuk memainkan dan mengelola media, seperti musik atau video.;Android menyediakan beberapa jenis media player, seperti MediaPlayer atau ExoPlayer, yang dapat disesuaikan dengan menggunakan kode Kotlin.;Media player dapat digunakan untuk memutar media dari berbagai sumber, seperti file lokal atau streaming dari internet."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "f5b82c7d-c3d3-4651-b86b-129845330cf0",
      "UserLikeCourse": false,
      "Title": "Submission Aplikasi Story App",
      "Description": "Cara mengimplementasikan komponen advanced untuk membuat aplikasi yang dapat register, login, dan upload data.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Submission Aplikasi Story App adalah tahapan pengiriman aplikasi ke Google Play Store untuk dapat diunduh oleh pengguna.;Tahapan ini meliputi persiapan aplikasi, seperti mengoptimalkan aplikasi dan memperbaiki bug, hingga proses pengiriman aplikasi ke Google Play Store dengan memenuhi kriteria dan persyaratan yang ditetapkan.;Setelah aplikasi dikirim, developer dapat melihat performa aplikasi dan mengembangkan fitur baru untuk meningkatkan kualitas dan pengalaman pengguna."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "f814f935-8357-4c93-a19c-40d2330ad931",
      "UserLikeCourse": false,
      "Title": "Geo Location",
      "Description": "Memahami bagaimana menampilkan peta/maps menggunakan Google Maps API, mendapatkan posisi pengguna (latitude dan longitude) menggunakan Location Service serta mendapatkan informasi menarik dari radius dan posisi tertentu menggunakan Geofences.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Geo Location adalah teknologi yang digunakan pada aplikasi Android untuk mengetahui lokasi pengguna menggunakan GPS atau jaringan seluler.;Android menyediakan beberapa API untuk geo location, seperti Fused Location Provider API atau Geocoder API, yang dapat disesuaikan dengan menggunakan kode Kotlin.;Geo location dapat digunakan untuk mengembangkan fitur pada aplikasi, seperti peta atau notifikasi berdasarkan lokasi."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "958a6f7f-3935-4c07-8248-096d10387ec4",
      "UserLikeCourse": false,
      "Title": "Advanced Testing",
      "Description": "Mengetahui berbagai pendekatan dalam menguji aplikasi, baik secara unit testing menggunakan Test Double, maupun UI testing menggunakan Idling Resource maupun MockWebServer.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Advanced Testing adalah teknik pengujian pada aplikasi Android yang lebih kompleks dan canggih, seperti pengujian integrasi atau pengujian kinerja.;Advanced Testing dapat membantu developer untuk menemukan bug dan meningkatkan kualitas aplikasi sebelum dirilis.;Advanced Testing memerlukan pengetahuan yang lebih mendalam pada teknologi pengembangan Android dan bahasa pemrograman Kotlin atau Java."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "f281ead4-8b0d-4928-b7b4-a71aad25a671",
      "UserLikeCourse": false,
      "Title": "Advanced Database",
      "Description": "14. Mendalami lebih lanjut terkait penggunaan database di skala industri, seperti relasi antar database, pre populate database, migrasi database, RawQuery, serta implementasi Paging.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Advanced Database adalah teknik pengembangan pada aplikasi Android untuk mengatur dan mengelola data yang kompleks dan besar.;Android menyediakan beberapa jenis database, seperti SQLite atau Room, yang dapat disesuaikan dengan menggunakan kode Kotlin.;Advanced Database dapat memberikan kinerja yang lebih cepat dan efisien pada aplikasi dengan mengoptimalkan penggunaan memori dan mengatur struktur data yang tepat."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "fce5c4b7-9cdf-4dea-8bcb-9793556e06ce",
      "UserLikeCourse": false,
      "Title": "Firebase",
      "Description": "Memahami berbagai layanan Firebase yang biasa digunakan, seperti Authentication, Realtime Database, serta Firebase Cloud Messaging (FCM).",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Firebase adalah platform pengembangan aplikasi mobile dari Google yang menyediakan berbagai fitur untuk pengembangan aplikasi Android, seperti hosting, database, authentication, atau notification.;Firebase menyediakan SDK yang dapat disesuaikan dengan menggunakan kode Kotlin atau Java.;Firebase dapat membantu developer untuk mengembangkan aplikasi dengan cepat dan efisien dengan menyediakan infrastruktur yang diperlukan."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "b9518aa2-8a6c-4e26-9b8f-0f0d9ce67799",
      "UserLikeCourse": false,
      "Title": "Object-Oriented Programming (OOP)",
      "Description": "Mengenalkan pilar OOP yakni Inheritance, Encapsulation, Abstraction, dan Polymorphism.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "OOP adalah paradigma pemrograman yang berfokus pada objek sebagai unit dasar dari program.;Pada OOP, objek memiliki atribut dan metode yang dapat diakses oleh objek lain atau bagian program lainnya.;OOP menyediakan prinsip-prinsip seperti inheritance, encapsulation, dan polymorphism untuk mempermudah pengembangan aplikasi yang kompleks."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "4fa72421-9432-42fb-888b-40b29e033f02",
      "UserLikeCourse": false,
      "Title": "Relasi pada OOP",
      "Description": "Mengetahui macam-macam hubungan antar objek di OOP seperti association, agregation, composition, dependency, generalization, specialization, dan implementation.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Pada OOP, relasi antar objek dapat dijelaskan melalui beberapa konsep seperti inheritance, composition, aggregation, atau association.;Inheritance adalah relasi dimana suatu objek memiliki atribut atau metode dari objek lain yang menjadi parent-nya.;Composition adalah relasi dimana suatu objek dibentuk oleh beberapa objek lain yang menjadi bagian dari objek tersebut."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "ce1f9f72-a7d3-44b8-881d-ba70da16c7eb",
      "UserLikeCourse": false,
      "Title": "Software Design Principle",
      "Description": "Menjelaskan tentang kenapa seorang developer harus memahami software design principle jika ingin membangun suatu aplikasi yang berbasis OOP. Dipelajari juga 3 karakteristik penting dari design buruk yang perlu dihindari yakni rigidity, fragility, dan immobility.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Software Design Principle adalah seperangkat prinsip dan aturan yang digunakan untuk mengembangkan desain perangkat lunak yang baik dan mudah dimengerti.;Beberapa prinsip yang termasuk dalam Software Design Principle adalah KISS (Keep It Simple, Stupid), DRY (Don't Repeat Yourself), dan YAGNI (You Ain't Gonna Need It).;Prinsip-prinsip ini membantu developer untuk mengembangkan perangkat lunak yang mudah dimengerti, mudah dirawat, dan mudah diubah di masa depan."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "d8538256-7d01-4a3b-be59-33f2b12e1d4e",
      "UserLikeCourse": false,
      "Title": "S.O.L.I.D",
      "Description": "Mengenalkan satu per satu prinsip dari SOLID yaitu Single Responsibility, Open Closed, Liskov Substitution, Interface Segregation, dan Dependency Inversion.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "S.O.L.I.D adalah sebuah akronim yang mewakili lima prinsip desain perangkat lunak berorientasi objek.;S.O.L.I.D adalah singkatan dari Single Responsibility Principle (SRP), Open/Closed Principle (OCP), Liskov Substitution Principle (LSP), Interface Segregation Principle (ISP), dan Dependency Inversion Principle (DIP).;S.O.L.I.D membantu developer untuk mengembangkan perangkat lunak yang mudah dimengerti, fleksibel, dan mudah diubah di masa depan."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "0700118d-8b0c-4eae-9157-8e90e357a6a9",
      "UserLikeCourse": false,
      "Title": "Clean Architecture",
      "Description": "Berbagai macam design pattern yang biasa digunakan dalam pengembangan aplikasi Android seperti Clean Architecture untuk membangun aplikasi yang tertata dan mudah dipelihara.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Clean Architecture adalah sebuah pendekatan desain perangkat lunak yang berfokus pada pemisahan kode menjadi beberapa layer atau lapisan.;Clean Architecture terdiri dari beberapa layer seperti domain, use case, infrastructure, atau presentation, dan masing-masing layer memiliki tanggung jawab yang berbeda.;Clean Architecture membantu developer untuk mengembangkan perangkat lunak yang mudah dimengerti, mudah diuji, dan mudah diubah di masa depan."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "28660410-339c-4338-924f-66c7846d27f7",
      "UserLikeCourse": false,
      "Title": "Reactive Programming",
      "Description": "Implementasi paradigma pemrograman deklaratif menggunakan dua library yang sudah cukup terkenal, yakni RX dan Coroutine Flow.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Reactive Programming adalah paradigma pemrograman yang berfokus pada pengolahan data secara asinkronus.;Reactive Programming menggunakan beberapa konsep seperti observable, observer, atau stream untuk memudahkan pengolahan data secara real-time.;Reactive Programming dapat membantu developer untuk mengembangkan aplikasi yang responsif dan efisien dengan meminimalkan penggunaan thread."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "b058d0cb-1a49-4bc0-8e2b-df3684b27fff",
      "UserLikeCourse": false,
      "Title": "Dependency Injection",
      "Description": "Teknik untuk membangun aplikasi yang kokoh melalui penggunaan Dagger dan Koin.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Dependency Injection adalah sebuah konsep desain perangkat lunak yang digunakan untuk meminimalkan ketergantungan antar komponen pada aplikasi.;Dependency Injection mengikuti prinsip Inversion of Control (IoC) dimana kontrol alur program dipindahkan dari aplikasi ke framework atau container.;Dependency Injection membantu mempermudah pengembangan aplikasi yang kompleks dengan memisahkan logika bisnis dari detail implementasi teknis."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "a6353154-3d92-46aa-b14a-199d6ab1072c",
      "UserLikeCourse": false,
      "Title": "Modularization",
      "Description": "Cara membangun aplikasi berskala besar melalui paham Modularization untuk membuat module, baik berupa Android Library maupun Dynamic Feature.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Modularization adalah sebuah pendekatan desain perangkat lunak yang memecah aplikasi menjadi beberapa modul independen yang saling terhubung.;Setiap modul pada modularization memiliki tanggung jawab yang berbeda-beda dan dapat dikembangkan secara independen.;Modularization membantu developer untuk mengembangkan aplikasi yang lebih terstruktur, mudah diuji, dan mudah diubah di masa depan."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "355f43ed-8eda-46f5-b5e9-e0af252dcaad",
      "UserLikeCourse": false,
      "Title": "Capstone Proyek Aplikasi Android",
      "Description": "Menguji pemahaman siswa dalam implementasi pengetahuan dengan cara menerapkan Clean Architecture, Dependency Injection, Reactive Programming, dan Modularization pada aplikasi dengan tema bebas.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Capstone Proyek adalah sebuah proyek akhir pada program belajar Android yang mengharuskan peserta untuk mengembangkan aplikasi Android dari awal hingga selesai.;Capstone Proyek memungkinkan peserta untuk mengaplikasikan semua konsep dan teknik yang telah dipelajari selama belajar Android.;Capstone Proyek membantu peserta untuk memperdalam pemahaman dan keterampilan dalam mengembangkan aplikasi Android yang sesuai dengan kebutuhan pengguna."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "e62916ed-8ed1-4859-ad59-292a9118daee",
      "UserLikeCourse": false,
      "Title": "Continuous Integration",
      "Description": "Proses otomatisasi untuk mempermudah pengujian aplikasi.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Continuous Integration adalah sebuah metode pengembangan perangkat lunak yang mengintegrasikan kode dari beberapa developer secara terus-menerus.;Continuous Integration memungkinkan developer untuk memperbarui kode dan menguji perubahan pada aplikasi secara otomatis dengan setiap perubahan pada kode.;Continuous Integration membantu meminimalkan kesalahan dan memastikan bahwa setiap perubahan pada kode dapat diintegrasikan dengan baik pada aplikasi."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "fec3d976-f1c6-410f-bc1c-d178bfaefc5b",
      "UserLikeCourse": false,
      "Title": "Performance",
      "Description": "Best practice mengenai aspek aplikasi yang dapat ditingkatkan performanya beserta cara implementasinya.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Performance adalah sebuah faktor penting pada pengembangan aplikasi Android yang harus diperhatikan oleh developer.;Performance dapat mempengaruhi pengalaman pengguna pada aplikasi seperti kecepatan loading atau respon aplikasi.;Developer harus memperhatikan faktor-faktor seperti ukuran file, penggunaan memori, atau efisiensi kode untuk meningkatkan performa aplikasi."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "8b10209a-07c0-4a3c-a017-a45fe323dca1",
      "UserLikeCourse": false,
      "Title": "Security",
      "Description": "Best practice mengenai aspek keamanan aplikasi beserta cara implementasinya.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Security adalah sebuah faktor penting pada pengembangan aplikasi Android untuk melindungi data dan informasi pengguna.;Developer harus memperhatikan keamanan pada aplikasi seperti mencegah serangan hacker, perlindungan data pengguna, atau penggunaan SSL untuk memperkuat keamanan data.;Developer juga harus memastikan bahwa aplikasi memenuhi standar keamanan yang diperlukan seperti PCI atau HIPAA."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "c8e4f0cc-fda8-4dca-8a1d-fe8a44b54672",
      "UserLikeCourse": false,
      "Title": "Build App with Useful Libraries",
      "Description": "Cara menggunakan library yang sering digunakan oleh perusahaan atau industri global seperti Timber, Firebase Crashlytics, Shimmer, Lottie, dan MapBox.",
      "Tag": [
        "Mobile"
      ],
      "Summary": "Library adalah sebuah kumpulan kode yang dapat digunakan oleh developer untuk mempercepat pengembangan aplikasi.;Ada banyak library yang tersedia untuk pengembangan aplikasi Android seperti Retrofit untuk mengakses API, Glide untuk memproses gambar, atau Room untuk database.;Penggunaan library yang tepat dapat membantu developer mengembangkan aplikasi yang lebih cepat, efisien, dan terstruktur."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "0a28e48b-ce0b-4d1a-9a51-0243f9e61073",
      "UserLikeCourse": false,
      "Title": "Persiapan Data Pra-Visualisasi",
      "Description": "Pengenalan tentang tools aplikasi spreadsheet menggunakan Google Sheets mulai dari navigasi hingga fungsi-fungsi yang bisa digunakan untuk mengolah data. (8 jam 14 menit)",
      "Tag": [
        "Data"
      ],
      "Summary": "Persiapan Data Pra-Visualisasi adalah proses persiapan data sebelum data tersebut divisualisasikan.;Proses ini meliputi pembersihan data, penggabungan data, pengubahan format data, penghapusan data yang tidak relevan, dan lainnya.;Tujuan dari Persiapan Data Pra-Visualisasi adalah untuk memastikan data yang akan divisualisasikan dalam kondisi yang sesuai dan tepat."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "4292f1d5-4cd8-4a32-a93a-7614776fad97",
      "UserLikeCourse": true,
      "Title": "Transformasi Data ke Visual",
      "Description": "Cara untuk mengubah data menjadi bentuk grafik, kesalahan umum dalam visualisasi data, pentingnya dokumentasi data, bagaimana cara bercerita dengan data, dan praktek terbaik dalam visualisasi yang efektif seperti prinsip Gestalt, konsep Preattentive Attributes, dan konsep teori desain. (4 jam 29 menit)",
      "Tag": [
        "Data"
      ],
      "Summary": "Transformasi Data ke Visual adalah proses mengubah data menjadi bentuk visual yang dapat dipahami oleh pengguna.;Visualisasi data dapat berupa grafik, chart, atau visual lainnya yang menampilkan data secara efektif.;Tujuan dari Transformasi Data ke Visual adalah untuk membantu pengguna dalam memahami data dengan lebih mudah dan cepat."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "a67d3c9c-8867-4edd-a9cc-c09b69477792",
      "UserLikeCourse": false,
      "Title": "Dasar Python",
      "Description": "Menjelaskan mode operasi dan style guide penulisan pada Python.",
      "Tag": [
        "Data"
      ],
      "Summary": "Python adalah bahasa pemrograman tingkat tinggi yang digunakan untuk pengembangan aplikasi, analisis data, dan pengembangan web.;Python memiliki sintaks yang mudah dipahami dan fleksibel, serta memiliki banyak library dan framework yang dapat digunakan untuk mempercepat pengembangan aplikasi.;Penggunaan Python pada pengembangan aplikasi semakin populer karena kemampuannya dalam mengolah data dan mudah digunakan untuk Machine Learning dan Artificial Intelligence."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "3ea58645-2bd7-4c0f-a0d1-79b0bc6a1ed4",
      "UserLikeCourse": false,
      "Title": "Tipe Data pada Python",
      "Description": "Menjelaskan tipe data pada Python, seperti Number, String, List, dan Set.",
      "Tag": [
        "Data"
      ],
      "Summary": "Python memiliki beberapa tipe data seperti integer, float, string, boolean, dan lainnya.;Tipe data pada Python dapat diubah dengan fungsi konversi seperti int(), float(), str(), bool(), dan lainnya.;Penggunaan tipe data yang tepat sangat penting dalam pengembangan aplikasi untuk memastikan keakuratan data dan efisiensi dalam penggunaan memori."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "169d1398-65ac-4af2-bd9c-288c725db969",
      "UserLikeCourse": false,
      "Title": "Input/Output dan Operasi pada Python",
      "Description": "Menjelaskan mekanisme input/output pada Python, dan juga operasi pada Python seperti operasi pada list, manipulasi string, operator, operands, dan expression.",
      "Tag": [
        "Data"
      ],
      "Summary": "Input dan Output pada Python dilakukan dengan fungsi input() dan print().;Operasi pada Python meliputi operasi matematika seperti penjumlahan, pengurangan, perkalian, dan pembagian, serta operasi lainnya seperti pembandingan, logika, dan bitwise.;Penggunaan input/output dan operasi pada Python sangat penting dalam pengembangan aplikasi untuk memproses data dan memberikan output yang sesuai."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "25052432-01a1-4cf0-b3ef-32e6be5b9431",
      "UserLikeCourse": false,
      "Title": "Style Guide pada Python",
      "Description": "Menjelaskan style guide pada Python, PEP8, formatting kode, statement gabungan, dan prinsip penamaan. (1 jam 50 menit)",
      "Tag": [
        "Data"
      ],
      "Summary": "Style Guide pada Python adalah sebuah panduan dalam penulisan kode Python yang baik dan benar.;Panduan ini meliputi aturan dalam penamaan variabel, indentasi, pemisahan baris, komentar, dan lainnya.;Penggunaan Style Guide pada Python sangat penting dalam pengembangan aplikasi untuk memastikan kode yang mudah dibaca, dipahami, dan di-maintain oleh developer lain."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "09e96fee-9c33-4631-84d4-82c4429eb02c",
      "UserLikeCourse": false,
      "Title": "Control Flow",
      "Description": "Menjelaskan flow control pada Python, percabangan dan perulangan.",
      "Tag": [
        "Data"
      ],
      "Summary": "Control Flow adalah proses pengontrolan alur program pada Python yang meliputi kondisional, perulangan, dan fungsi.;Kondisional pada Python meliputi penggunaan if-else statement dan operator logika.;Perulangan pada Python meliputi penggunaan for loop dan while loop."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "901d6e44-5678-4c46-af83-cd65f986ac55",
      "UserLikeCourse": true,
      "Title": "Penanganan Kesalahan",
      "Description": "Menjelaskan cara menangani kesalahan ketika terjadi kesalahan syntax atau pengecualian di Python.",
      "Tag": [
        "Data"
      ],
      "Summary": "Python memiliki fitur penanganan kesalahan (error handling) dengan menggunakan try-except-finally.;Dalam blok try, kode yang berpotensi menyebabkan kesalahan (exception) ditempatkan, dan jika terjadi kesalahan maka blok except akan menangani kesalahan tersebut.;Ada berbagai jenis exception di Python, seperti KeyError, ValueError, dan TypeError."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "ae45d028-e8ad-477c-b42f-e68840cb5b4c",
      "UserLikeCourse": false,
      "Title": "Fungsi dan Method",
      "Description": "Menjelaskan fungsi dan method pada Python, argument, dan parameter.",
      "Tag": [
        "Data"
      ],
      "Summary": "Fungsi dan method merupakan blok kode yang dapat digunakan berulang kali dalam program.;Fungsi adalah blok kode yang dipanggil oleh nama dan dapat menerima parameter.;Method adalah fungsi yang terkait dengan objek dan dapat diakses melalui objek."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "d0df47d8-55c6-46c9-bb2b-4b46dbba8f29",
      "UserLikeCourse": false,
      "Title": "Pemrograman Berorientasi Objek",
      "Description": "Menjelaskan pemrograman berorientasi objek pada Python seperti object, class, method, inheritance, dan implementation.",
      "Tag": [
        "Data"
      ],
      "Summary": "Pemrograman berorientasi objek (OOP) adalah paradigma pemrograman yang menggunakan objek sebagai pusatnya.;Objek memiliki atribut (data) dan metode (fungsi) yang dapat diakses oleh objek lain.;OOP memiliki konsep pewarisan (inheritance), dimana sebuah kelas dapat mewarisi atribut dan metode dari kelas lain."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "e30eaf0d-d883-45ff-b754-703f4e953aa1",
      "UserLikeCourse": false,
      "Title": "Unit Testing",
      "Description": "Memahami teknik pengujian program secara otomatis pada Python dengan unit testing beserta contoh implementasinya. ",
      "Tag": [
        "Data"
      ],
      "Summary": "Unit testing adalah proses menguji setiap bagian dari kode secara terpisah untuk memastikan bahwa kode berfungsi dengan benar.;Python memiliki library bawaan, seperti unittest dan pytest, untuk melakukan unit testing.;Test case harus menguji setiap kemungkinan output yang mungkin dihasilkan oleh fungsi atau method yang diuji."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "c3c540b8-875d-4299-8aa2-2fc11530a6b9",
      "UserLikeCourse": false,
      "Title": "Library Populer pada Python",
      "Description": "Mempelajari beberapa library populer pada Python seperti String, OS, Pickle, JSON, Scrapper, Regex, dan Argument Parser.",
      "Tag": [
        "Data"
      ],
      "Summary": "Python memiliki banyak library populer yang dapat membantu mengembangkan program, seperti NumPy, Pandas, dan Matplotlib.;NumPy adalah library untuk melakukan komputasi numerik, seperti operasi matriks dan array.;Pandas adalah library untuk melakukan manipulasi data, seperti pemrosesan data dan analisis data."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "ed981b7a-cb5a-4ee6-9417-549c4def541f",
      "UserLikeCourse": false,
      "Title": "Supervised dan Unsupervised Learning",
      "Description": "Memahami 2 jenis machine learning yaitu supervised dan unsupervised learning, dengan contoh model regresi linear dan decision tree.",
      "Tag": [
        "Data"
      ],
      "Summary": "Supervised learning adalah teknik pembelajaran mesin yang melibatkan input dan output data terlabel.;Unsupervised learning adalah teknik pembelajaran mesin yang melibatkan input data tanpa label.;Supervised learning dapat digunakan untuk melakukan klasifikasi dan regresi, sementara unsupervised digunakan untuk clustering"
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "9b981453-8835-4515-b1cf-50894ecd4986",
      "UserLikeCourse": false,
      "Title": "Support Vector Machine (SVM)",
      "Description": "Menjelaskan tentang SVM, salah satu model machine learning yang populer. Di sini juga akan belajar tentang clustering dengan k-means.",
      "Tag": [
        "Data"
      ],
      "Summary": "SVM adalah algoritma pembelajaran mesin yang digunakan untuk klasifikasi atau regresi.;SVM bekerja dengan menemukan hyperplane yang terbaik memisahkan dua kelas.;SVM dapat diaplikasikan pada data dengan dimensi yang tinggi dan memiliki kompleksitas yang tinggi."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "41612840-6cfd-453f-900b-f612208ac3b3",
      "UserLikeCourse": false,
      "Title": "Dasar-Dasar Machine Learning",
      "Description": "Menjelaskan tentang alur kerja (workflow) dari suatu proyek machine learning, dan juga menjelaskan overfitting, underfitting, dan model selection.",
      "Tag": [
        "Data"
      ],
      "Summary": "Machine learning adalah bidang kecerdasan buatan yang memungkinkan komputer belajar dari data dan pengalaman untuk melakukan tugas tertentu tanpa diprogram secara eksplisit.;Ada tiga jenis pembelajaran mesin: supervised learning, unsupervised learning, dan reinforcement learning.;Tujuan dari machine learning adalah untuk membuat model yang dapat mempelajari pola dalam data dan menggunakan pola ini untuk melakukan prediksi atau klasifikasi pada data baru."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "6df48d83-5413-4731-8204-ea4b360f7515",
      "UserLikeCourse": false,
      "Title": "Neural Network",
      "Description": "Belajar mengenal dasar dari neural network. Akan diterangkan mengenai multi layer perceptron serta convolutional neural network dalam image classification.",
      "Tag": [
        "Data"
      ],
      "Summary": "Neural network adalah kumpulan algoritma pembelajaran mesin yang terinspirasi oleh struktur dan fungsi jaringan saraf otak manusia.;Neural network dapat digunakan untuk melakukan klasifikasi, regresi, dan pemrosesan bahasa alami.;Neural network terdiri dari lapisan (layer) dengan masing-masing lapisan terdiri dari neuron yang terhubung dengan lapisan lainnya."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "03e51c07-8b29-4e1e-872e-19465f10b3ad",
      "UserLikeCourse": false,
      "Title": "TensorFlow",
      "Description": "Belajar tentang library TensorFlow, sebuah powerful library yang dipakai untuk mengembangkan project machine learning.",
      "Tag": [
        "Data"
      ],
      "Summary": "TensorFlow adalah framework open-source yang digunakan untuk membangun dan melatih model machine learning.;TensorFlow memungkinkan untuk membangun dan melatih model neural network dan model machine learning lainnya.;TensorFlow memiliki banyak fitur dan kemampuan, seperti kemampuan untuk melatih model di banyak GPU dan TPU."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "88e8894f-d303-43c4-9a4c-cd227178b211",
      "UserLikeCourse": false,
      "Title": "Problem Framing",
      "Description": "Mempelajari bagaimana merumuskan solusi machine learning untuk suatu masalah.",
      "Tag": [
        "Data"
      ],
      "Summary": "Problem framing adalah proses menentukan masalah yang ingin diselesaikan dengan machine learning, menentukan tujuan dari model, dan memahami batasan dan kendala dari masalah tersebut.;Langkah ini sangat penting dalam membangun model machine learning yang efektif dan bermanfaat.;Problem framing membantu dalam memilih algoritma machine learning yang tepat, mengumpulkan data yang diperlukan, dan mengevaluasi performa model."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "78f14e95-57b4-4c82-b415-60cfbb7f8a44",
      "UserLikeCourse": false,
      "Title": "Membuat dan Melatih Model Neural Network dengan Tensorflow dan Keras",
      "Description": "Belajar mengembangkan model dengan format data berbeda, membuat plot akurasi dan loss dari model, penggunaan callback, TensorFlow dataset, dan batch loading.",
      "Tag": [
        "Data"
      ],
      "Summary": "TensorFlow dan Keras adalah framework yang digunakan untuk membangun dan melatih model neural network.;TensorFlow menyediakan berbagai alat dan fitur untuk membangun model, sementara Keras menyediakan antarmuka yang lebih mudah digunakan untuk membangun model neural network.;Langkah-langkah umum untuk membuat dan melatih model neural network adalah menentukan arsitektur model, memilih algoritma pembelajaran, menyiapkan data, melatih model, dan mengevaluasi performa model."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "b05e4968-f535-4e9e-8557-0c6aa48abc00",
      "UserLikeCourse": false,
      "Title": "Sistem Rekomendasi",
      "Description": "Mengenal teknik yang dipakai dalam sistem rekomendasi seperti collaborative dan content based filtering, serta sistem rekomendasi menggunakan jaringan saraf.",
      "Tag": [
        "Data"
      ],
      "Summary": "Sistem rekomendasi adalah algoritma yang digunakan untuk merekomendasikan item atau konten yang cocok untuk pengguna berdasarkan preferensi dan riwayat penggunaan.;Sistem rekomendasi dapat digunakan pada berbagai jenis konten, seperti musik, film, buku, produk, dan lain sebagainya.;Sistem rekomendasi dapat menggunakan beberapa teknik, seperti kolaboratif filtering, rekomendasi berbasis konten, dan hybrid recommendation."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "e72c59f6-e7ce-456f-bee9-688678f7cad8",
      "UserLikeCourse": false,
      "Title": "Klasifikasi Gambar",
      "Description": "Mengembangkan model untuk klasifikasi gambar dan teknik yang umum dipakai di industri.",
      "Tag": [
        "Data"
      ],
      "Summary": "Klasifikasi gambar adalah salah satu tugas dalam machine learning yang bertujuan untuk mengelompokkan gambar-gambar ke dalam kategori tertentu berdasarkan ciri-ciri visual yang dimiliki oleh gambar tersebut.;Teknik-teknik yang sering digunakan dalam klasifikasi gambar antara lain Convolutional Neural Networks (CNN), transfer learning, dan data augmentation.;Evaluasi performa model klasifikasi gambar dapat dilakukan menggunakan metrics seperti accuracy, precision, recall, dan F1-score."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "d34b84b6-0750-4c49-94ae-b8041449acac",
      "UserLikeCourse": false,
      "Title": "Natural Language Processing (NLP) dengan TensorFlow",
      "Description": "Belajar mengolah kata menggunakan TensorFlow.",
      "Tag": [
        "Data"
      ],
      "Summary": "NLP adalah salah satu cabang dari machine learning yang berfokus pada pengolahan bahasa alami manusia.;TensorFlow merupakan salah satu framework machine learning yang dapat digunakan untuk membangun model NLP.;Teknik-teknik dalam NLP meliputi preprocessing text, tokenization, embedding, dan language models."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "d595a9eb-50ce-4bbf-b53f-a46841a7e325",
      "UserLikeCourse": false,
      "Title": "Time Series",
      "Description": "Belajar mengembangkan model untuk prediksi data time series.",
      "Tag": [
        "Data"
      ],
      "Summary": "Time series adalah kumpulan data yang terjadi dalam urutan waktu yang teratur, sehingga terdapat ketergantungan antara data satu dengan yang lainnya.;Beberapa teknik dalam time series analysis antara lain ARIMA, exponential smoothing, dan Prophet.;Evaluasi performa model time series dapat dilakukan menggunakan metrics seperti MAE, MSE, RMSE, dan MAPE."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "36eabd06-f252-4ff1-a8a2-5efe5c88208e",
      "UserLikeCourse": true,
      "Title": "Reinforcement Learning",
      "Description": "Teknik melatih model berdasarkan teori hadiah dan hukuman, menggunakan Keras, game playing agent, serta algoritma minimax.",
      "Tag": [
        "Data"
      ],
      "Summary": "Reinforcement Learning adalah salah satu metode machine learning yang mempelajari bagaimana agen (agent) harus melakukan tindakan (action) dalam suatu lingkungan (environment) untuk mencapai tujuan tertentu (reward).;Teknik-teknik dalam reinforcement learning meliputi value-based, policy-based, dan model-based.;Beberapa aplikasi reinforcement learning antara lain dalam game AI, robotik, dan optimasi jaringan."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "4ed54a74-0b45-4605-8604-aea99f600ec4",
      "UserLikeCourse": false,
      "Title": "Deployment",
      "Description": "Menjelaskan bagaimana men-deploy model machine learning ke aplikasi website dan Android dengan menggunakan TensorFlow",
      "Tag": [
        "Data"
      ],
      "Summary": "Deployment adalah tahap terakhir dari siklus pengembangan machine learning, yaitu saat model yang telah dibangun akan diimplementasikan pada lingkungan produksi.;Beberapa teknologi untuk deployment machine learning antara lain Docker, Kubernetes, dan serverless computing.;Penting untuk memastikan bahwa model yang di-deploy sudah diuji dan dievaluasi sebelumnya, serta tetap diawasi dan diperbarui secara berkala."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "cbd0f847-43ce-401a-b660-d3daf3fc9736",
      "UserLikeCourse": false,
      "Title": "Machine Learning System Design",
      "Description": "Mempelajari tahapan-tahapan dalam menyusun sistem machine learning dan memahami desain sistem machine learning.",
      "Tag": [
        "Data"
      ],
      "Summary": "Machine learning system design berkaitan dengan bagaimana merancang dan mengembangkan sistem yang dapat memanfaatkan kecerdasan buatan (AI) untuk memecahkan masalah bisnis yang spesifik.;Proses desain meliputi pemilihan data yang dibutuhkan, pemilihan model yang sesuai, pengembangan pipeline data, dan pengaturan infrastruktur yang dibutuhkan.;Kunci dari machine learning system design adalah memastikan bahwa model yang dihasilkan dapat diimplementasikan dengan baik dan memberikan nilai tambah bagi bisnis."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "ee9bbaa5-bc3e-4cec-ab9f-77c5212b15d4",
      "UserLikeCourse": false,
      "Title": "Menyusun Proyek Machine Learning",
      "Description": "Mempelajari bagaimana tahapan dalam menyusun proyek machine learning, mampu mengomunikasikan dan memublikasikan proyek machine learning untuk membangun portofolio.",
      "Tag": [
        "Data"
      ],
      "Summary": "Menyusun proyek machine learning adalah proses yang melibatkan pemilihan dan definisi permasalahan yang ingin diselesaikan, pengumpulan data, eksplorasi data, pemilihan model, dan evaluasi model.;Penting untuk memastikan bahwa proyek machine learning yang dibangun memiliki value proposition yang jelas dan menghasilkan hasil yang dapat diimplementasikan.;Proyek machine learning dapat digunakan untuk berbagai macam aplikasi, seperti prediksi harga saham, deteksi spam"
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "4120e7e4-e3ba-46a3-8b16-274bcab72a9f",
      "UserLikeCourse": false,
      "Title": "Studi Kasus Pertama : Predictive Analytics",
      "Description": "Mempelajari algoritma k-Nearest Neighbor, Random Forest, dan AdaBoost serta penerapannya untuk kasus predictive analytics.",
      "Tag": [
        "Data"
      ],
      "Summary": "Predictive Analytics adalah teknik untuk menganalisis data historis dan memprediksi hasil masa depan.;Tujuan utama dari Predictive Analytics adalah untuk memperoleh wawasan bisnis yang dapat membantu organisasi membuat keputusan yang lebih baik.;Langkah-langkah umum dalam membangun model Predictive Analytics meliputi: pemahaman bisnis, pengumpulan dan persiapan data, pemilihan fitur, pembangunan model, validasi model, dan implementasi model."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "8c45e429-9d83-44b7-8faf-8d32f6da7e85",
      "UserLikeCourse": false,
      "Title": "Studi Kasus Kedua : Sentiment Analysis",
      "Description": "Mempelajari bagaimana membuat model analisis sentimen dengan teknik Deep Learning dan Support Vector Machine.",
      "Tag": [
        "Data"
      ],
      "Summary": "Sentiment Analysis adalah teknik untuk menganalisis sentimen atau perasaan dalam teks, seperti positif, negatif, atau netral.;Tujuan utama dari Sentiment Analysis adalah untuk memahami pandangan atau opini pengguna tentang suatu topik atau produk.;Langkah-langkah umum dalam membangun model Sentiment Analysis meliputi: pengumpulan dan persiapan data, pemilihan algoritma, pembangunan model, validasi model, dan implementasi model."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "c11422bc-c380-4bb3-803e-fc4ab4395946",
      "UserLikeCourse": true,
      "Title": "Proyek Pertama",
      "Description": "Menguji pemahaman peserta dalam membuat proyek machine learning dengan tema Predictive Analytics, membuat laporan proyek dengan prinsip CRISP-DM, dan membuat laporan proyek berformat .md atau .txt",
      "Tag": [
        "Data"
      ],
      "Summary": "Proyek Pertama adalah proyek dasar dalam Machine Learning untuk mengembangkan pemahaman tentang konsep dan teknik Machine Learning.;Proyek ini sering melibatkan pemrosesan data, pemilihan fitur, pembangunan model, validasi model, dan evaluasi kinerja model.;Contoh proyek Machine Learning sederhana termasuk klasifikasi spam email, prediksi harga saham, dan deteksi wajah pada gambar."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "f1bc6b6b-f0c5-457e-9b18-d97268745273",
      "UserLikeCourse": false,
      "Title": "Computer Vision",
      "Description": "Mempelajari teknik computer vision untuk pengenalan gambar dan deteksi objek pada gambar.",
      "Tag": [
        "Data"
      ],
      "Summary": "Computer Vision adalah cabang Machine Learning yang memungkinkan komputer untuk memahami gambar dan video.;Teknik-teknik Computer Vision meliputi pengenalan objek, deteksi wajah, segmentasi gambar, dan banyak lagi.;Contoh aplikasi Computer Vision termasuk kendaraan otonom, deteksi penipuan kartu kredit, dan pengenalan tulisan tangan."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "28f1f772-b6d5-42d0-acb1-cd82d5b5c216",
      "UserLikeCourse": false,
      "Title": "Sistem Rekomendasi",
      "Description": "Mempelajari metode yang digunakan dalam Sistem Rekomendasi serta mampu membuat proyek Sistem Rekomendasi.",
      "Tag": [
        "Data"
      ],
      "Summary": "Sistem Rekomendasi adalah teknik untuk merekomendasikan item kepada pengguna berdasarkan riwayat atau preferensi mereka.;Teknik-teknik Sistem Rekomendasi meliputi Collaborative Filtering, Content-Based Filtering, dan Hybrid Filtering.;Contoh aplikasi Sistem Rekomendasi termasuk Netflix, Amazon, dan Spotify."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "e7ef4c00-c98b-40ca-9037-9c0a8287e239",
      "UserLikeCourse": false,
      "Title": "Pengenalan Machine Learning Operations",
      "Description": "Mengetahui konsep dasar pengembangan dan pengoperasian sistem machine learning di industri.",
      "Tag": [
        "Data"
      ],
      "Summary": "Machine Learning Operations (MLOps) adalah praktik untuk mengelola dan menyediakan lingkungan yang dapat diulang dan konsisten untuk melatih, menguji, dan menerapkan model Machine Learning.;MLOps melibatkan otomatisasi, penerapan, dan manajemen siklus hidup model Machine Learning.;Contoh alat MLOps termasuk Kubeflow, MLflow, dan TensorBoard."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "81762628-b88d-4495-aae8-674399cfaf61",
      "UserLikeCourse": false,
      "Title": "Pengolahan Data dalam Machine Learning Pipeline",
      "Description": "Memahami konsep dan cara membuat komponen pengolahan data dalam machine learning pipeline menggunakan TFX.",
      "Tag": [
        "Data"
      ],
      "Summary": "Pengolahan data adalah tahap penting dalam Machine Learning Pipeline untuk mempersiapkan data mentah menjadi data yang siap diproses oleh algoritma Machine Learning.;Teknik-teknik pengolahan data meliputi preprocessing data, normalisasi data, dan ekstraksi fitur.;Contoh alat pengolahan data termasuk pandas, NumPy, dan Scikit-learn."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "ab3b4c0c-69a3-4e52-bb7d-29e530a95475",
      "UserLikeCourse": false,
      "Title": "Pengembangan dan Validasi Model Machine Learning",
      "Description": "Memahami teori dan cara membuat komponen pengembangan dan validasi model dalam machine learning pipeline menggunakan TFX.",
      "Tag": [
        "Data"
      ],
      "Summary": "Proses pengembangan model machine learning meliputi tahap-tahap seperti pemrosesan data, pemilihan algoritma, tuning parameter, dan evaluasi model.;Validasi model machine learning dilakukan dengan teknik seperti cross-validation dan holdout validation.;Model machine learning yang dikembangkan harus diuji secara menyeluruh untuk memastikan kualitas dan performanya."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "2aaf63d9-fbcb-421c-a540-420087e28e17",
      "UserLikeCourse": true,
      "Title": "Penerapan Model Machine Learning dalam Sistem Produksi",
      "Description": "Memahami prinsip dan cara menerapkan model machine learning dalam sistem produksi.",
      "Tag": [
        "Data"
      ],
      "Summary": "Penerapan model machine learning dalam sistem produksi melibatkan tahap deployment dan monitoring performa model.;Model machine learning yang diterapkan dalam sistem produksi harus diimplementasikan dengan baik dan disesuaikan dengan lingkungan produksi.;Monitoring performa model machine learning diperlukan untuk memastikan kualitas dan performa model selalu terjaga."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "8bcef1f5-dfc2-4bd4-bc86-aaa53f088986",
      "UserLikeCourse": false,
      "Title": "Proyek Pertama",
      "Description": "Menguji pemahaman peserta dalam membuat machine learning pipeline menggunakan TensorFlow Extended (TFX) dengan menerapkan kriteria-kriteria yang telah ditentukan",
      "Tag": [
        "Data"
      ],
      "Summary": "Proyek pertama pada pemrograman biasanya berupa aplikasi sederhana atau pengembangan website statis.;Pada proyek pertama, biasanya fokus pada konsep fundamental seperti variabel, kondisional, dan looping.;Proyek pertama dapat menjadi batu loncatan untuk mempelajari konsep-konsep yang lebih kompleks di masa depan."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "f582e608-580f-47de-84b8-5c3aed1d8a6f",
      "UserLikeCourse": false,
      "Title": "Python Clean Code",
      "Description": "Mampu menerapkan prinsip clean code dalam bahasa pemrograman Python untuk menghasilkan kode yang sesuai dengan standar industri",
      "Tag": [
        "Data"
      ],
      "Summary": "Clean code dalam Python sangat penting untuk memudahkan pembacaan dan pemeliharaan kode.;Beberapa prinsip clean code dalam Python meliputi penggunaan nama variabel yang jelas, menghindari duplikasi kode, dan memformat kode secara konsisten.;Penulisan kode yang bersih dan mudah dipahami akan mempermudah kolaborasi dengan tim dan mengurangi risiko terjadinya bug dan error."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "2da60ea4-426f-476d-9efe-bf9a2275bc07",
      "UserLikeCourse": false,
      "Title": "Pengenalan HTML",
      "Description": "Memberikan pemahaman fungsi HTML dalam website, memahami struktur dasar dokumen HTML dengan membangun halaman web sederhana.",
      "Tag": [
        "Web"
      ],
      "Summary": "HTML adalah bahasa markup untuk membuat halaman web.;HTML terdiri dari tag dan atribut yang digunakan untuk mengatur struktur, konten, dan tampilan halaman web.;Pengenalan HTML mencakup konsep dasar seperti membuat tag, menambahkan atribut, dan menambahkan teks dan gambar ke halaman web."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "e8cd3f1b-f5f2-48d8-9a32-ba89c1b54964",
      "UserLikeCourse": false,
      "Title": "Pendalaman HTML",
      "Description": "Belajar mengorganisasi konten dengan elemen semantik, mengenal beragam atribut, elemen paragraf, heading, gambar, list, dan lainnya. Memahami perbedaan inline dan block elemen.",
      "Tag": [
        "Web"
      ],
      "Summary": "Mengenal HTML5 sebagai versi terbaru HTML dan fitur-fitur yang disediakan.;Penerapan Semantic HTML, yaitu penggunaan tag HTML yang merepresentasikan arti dari konten yang terdapat dalam elemen tersebut.;Menggunakan Atribut Global HTML seperti class, id, style, dan lain-lain untuk memperbaiki struktur dan tampilan halaman web."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "5a99fbc1-c863-4f3f-b9a9-36b5994bbafb",
      "UserLikeCourse": false,
      "Title": "Pengenalan CSS",
      "Description": "Memahami peran CSS dalam pembuatan website, benefitnya, dan mengetahui penulisan sintaks dasar CSS dengan menerapkan beberapa basic styling pada elemen HTML.",
      "Tag": [
        "Web"
      ],
      "Summary": "CSS digunakan untuk mengatur tampilan halaman web yang dibuat dengan HTML.;CSS memungkinkan untuk mengubah warna, font, ukuran, dan layout halaman web.;Pengenalan CSS mencakup konsep dasar seperti membuat selector, menambahkan properti, dan mengatur tampilan teks dan gambar."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "c5bd5b8b-2b19-449b-9241-ae2d8a2daf49",
      "UserLikeCourse": false,
      "Title": "Pendalaman CSS",
      "Description": "Memahami lebih dalam mengenai selector CSS, memahami penerapan styling untuk font dan text (mengubah tipe dan ukuran font, mengubah warna teks, dsb.), memahami tentang foreground color dan background color, memahami konsep box model, dan layouting menggunakan float.",
      "Tag": [
        "Web"
      ],
      "Summary": "Penerapan CSS Box Model, yaitu memahami cara mengatur margin, padding, dan border pada elemen HTML.;Menerapkan Cascading dan Specificity pada CSS, yaitu cara mengatur prioritas penggunaan CSS untuk mengatur tampilan halaman web.;Penerapan CSS Layout, yaitu cara mengatur tata letak elemen HTML pada halaman web, seperti dengan menggunakan float, flexbox, atau grid."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "a8f6ccbc-e08b-4f5e-85a9-73e0bb051c24",
      "UserLikeCourse": false,
      "Title": "Layout Responsif dengan Flexbox",
      "Description": "Memahami tentang penggunaan flexbox sebagai teknik baru dalam menyusun layout yang mudah dan responsif pada beragam perangkat.",
      "Tag": [
        "Web"
      ],
      "Summary": "Flexbox adalah sebuah teknologi dalam CSS yang digunakan untuk membuat tata letak yang responsif.;Flexbox memungkinkan untuk membuat tata letak yang terdiri dari elemen-elemen dengan berbagai ukuran dan posisi yang berbeda-beda.;Flexbox memiliki dua konsep utama, yaitu flex container (wadah) dan flex item (elemen)."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "1e5eab81-8959-43e4-b6f2-de584cfe90cf",
      "UserLikeCourse": false,
      "Title": "Pengenalan JavaScript",
      "Description": "Pengenalan tentang apa itu JavaScript, bagaimana sejarahnya, dan beberapa alasan untuk mulai mempelajarinya.",
      "Tag": [
        "Web"
      ],
      "Summary": "JavaScript adalah bahasa pemrograman yang banyak digunakan dalam pengembangan web dan aplikasi.;JavaScript memungkinkan untuk menambahkan interaktivitas dan dinamisme pada halaman web.;JavaScript dapat digunakan untuk memanipulasi HTML dan CSS, mengambil data dari server, serta melakukan validasi dan pengolahan data di sisi klien."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "efe91caa-60aa-4982-852e-054bc12831a6",
      "UserLikeCourse": false,
      "Title": "Fundamental JavaScript",
      "Description": "Menjelaskan dasar logika dan sintaksis pemrograman menggunakan JavaScript, seperti variabel, tipe data, dan perulangan",
      "Tag": [
        "Web"
      ],
      "Summary": "JavaScript memiliki berbagai konsep fundamental, seperti variabel, tipe data, operator, dan kondisi.;JavaScript juga memiliki konsep pengulangan (looping) dan pengambilan keputusan (decision making) yang sangat penting.;JavaScript memiliki kemampuan untuk membuat fungsi dan objek, yang memungkinkan untuk membuat kode yang reusable dan modular."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "eb90e0d7-a42f-454b-b9ad-0fe5eeb8ba8b",
      "UserLikeCourse": false,
      "Title": "Struktur Data",
      "Description": "Menjelaskan bagaimana menyimpan dan mengelola data yang lebih kompleks menggunakan Object, Array, Map, dan Set.",
      "Tag": [
        "Web"
      ],
      "Summary": "Struktur data adalah cara untuk menyimpan dan mengorganisasi data dalam suatu program.;Beberapa jenis struktur data yang umum digunakan adalah array, objek, dan linked list.;Struktur data yang tepat dapat membantu mempermudah proses manipulasi data dan meningkatkan performa program."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "b9d1d755-1a54-4560-9bda-be0bb4f584fa",
      "UserLikeCourse": false,
      "Title": "Function",
      "Description": "Menjelaskan bagaimana mengelompokkan kode menjadi fungsi yang dapat dipanggil ulang.",
      "Tag": [
        "Web"
      ],
      "Summary": "Function adalah blok kode yang dapat dipanggil berulang kali.;Function dapat digunakan untuk membagi kode ke dalam bagian-bagian yang lebih kecil dan reusable.;Function juga dapat menerima argumen sebagai input dan mengembalikan nilai sebagai output."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "8052513c-9041-4bb9-9dbd-c4511d1e76b5",
      "UserLikeCourse": false,
      "Title": "Object-Oriented Programming (OOP)",
      "Description": "Menjelaskan konsep OOP pada JavaScript, bagaimana membuat class, properti, dan method dari class.",
      "Tag": [
        "Web"
      ],
      "Summary": "OOP adalah paradigma pemrograman yang berfokus pada objek dan relasi antar objek.;OOP mengandalkan konsep seperti encapsulation, inheritance, dan polymorphism.;Dalam OOP, program direpresentasikan sebagai kumpulan objek yang saling berinteraksi dan melakukan tugas tertentu."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "715040b1-7c40-41b7-84c5-a9961f319c72",
      "UserLikeCourse": false,
      "Title": "Functional Programming",
      "Description": "Memahami konsep functional programming seperti perilaku fungsi, lambda, dan higher-order.",
      "Tag": [
        "Web"
      ],
      "Summary": "Functional Programming adalah paradigma pemrograman yang fokus pada fungsi dan data yang immutable (tidak dapat diubah).;Dalam Functional Programming, fungsi dianggap sebagai objek utama yang dapat digunakan untuk melakukan operasi pada data.;Beberapa konsep penting dalam Functional Programming adalah pure function, higher-order function, dan lambda expression."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "1d274cdd-aa9f-4725-9ea7-8807b2c60eed",
      "UserLikeCourse": false,
      "Title": "Setup Environment",
      "Description": "Proses instalasi lingkungan pengembangan seperti Node.js dan IDE pada perangkat yang Anda miliki.",
      "Tag": [
        "Web"
      ],
      "Summary": "Setup Environment adalah proses untuk mempersiapkan lingkungan kerja yang dibutuhkan untuk mengembangkan aplikasi dengan bahasa pemrograman tertentu.;Langkah-langkah dalam Setup Environment dapat berbeda-beda tergantung pada sistem operasi dan bahasa pemrograman yang digunakan.;Setup Environment dapat meliputi instalasi dan konfigurasi tools seperti editor kode, interpreter atau compiler, dan library atau framework."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "220f23cc-de3a-44bd-94f5-22002b98542a",
      "UserLikeCourse": false,
      "Title": "Module",
      "Description": "Menjelaskan bagaimana beberapa berkas JavaScript dapat saling berkomunikasi dan berbagi data satu sama lain.",
      "Tag": [
        "Web"
      ],
      "Summary": "Module adalah cara untuk memecah kode menjadi bagian yang lebih kecil dan terorganisir dalam satu file yang dapat diimpor ke file lain.;Modul memungkinkan pengembang untuk menggunakan kode yang sama di beberapa bagian dari aplikasi tanpa perlu menyalin kode tersebut.;Modul adalah salah satu fitur penting dalam membangun aplikasi skala besar karena dapat meningkatkan fleksibilitas dan pengelolaan kode."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "9b489b3b-95b1-4e88-8ec8-38b33c6d37cc",
      "UserLikeCourse": false,
      "Title": "Penanganan Eror",
      "Description": "Menjelaskan bagaimana menangani kegagalan yang mungkin muncul dalam program sehingga tidak berdampak kepada pengguna.",
      "Tag": [
        "Web"
      ],
      "Summary": "Penanganan error pada JavaScript adalah proses memeriksa dan mengatasi kesalahan atau bug dalam kode.;Penanganan error pada JavaScript dapat dilakukan dengan menggunakan try-catch statement untuk menangani error yang terjadi saat program berjalan.;Penanganan error yang efektif dan tepat dapat membantu mencegah aplikasi dari terjadinya crash atau stop berjalan."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "1de99991-9463-47af-8629-a009a88b493f",
      "UserLikeCourse": false,
      "Title": "Asynchronous Process",
      "Description": "Menjelaskan bagaimana menangani dan membuat proses asynchronous pada JavaScript.",
      "Tag": [
        "Web"
      ],
      "Summary": "Asynchronous Process pada JavaScript adalah proses eksekusi kode yang tidak harus menunggu kode sebelumnya selesai dijalankan.;Asynchronous Process pada JavaScript dapat diimplementasikan menggunakan callback, promise, atau async-await.;Asynchronous Process pada JavaScript dapat membantu meningkatkan performa aplikasi web dan membuat aplikasi terasa lebih responsif."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "3319b282-5f07-456a-8c4e-537681317fe7",
      "UserLikeCourse": false,
      "Title": "Node Package Manager",
      "Description": "Mengenalkan beberapa library yang penting untuk ditambahkan ke dalam proyek aplikasi JavaScript.",
      "Tag": [
        "Web"
      ],
      "Summary": "Node Package Manager (NPM) adalah manajer paket untuk bahasa pemrograman JavaScript yang digunakan untuk mengelola dan mendistribusikan kode JavaScript.;NPM memungkinkan pengembang untuk menginstal, mengelola, dan mengatur dependensi dari proyek JavaScript.;NPM adalah alat yang penting dalam pengembangan aplikasi JavaScript karena memungkinkan pengembang untuk menggunakan dan mengintegrasikan banyak paket dan library open-source."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "3f146b50-8fd2-45ff-8be1-4c8adad60540",
      "UserLikeCourse": false,
      "Title": "JavaScript Testing",
      "Description": "Menjelaskan bagaimana melakukan pengujian otomatis pada kode JavaScript.",
      "Tag": [
        "Web"
      ],
      "Summary": "JavaScript Testing adalah proses pengujian kode JavaScript untuk memastikan bahwa kode berfungsi dengan benar dan memenuhi persyaratan fungsional dan non-fungsional.;JavaScript Testing dapat dilakukan dengan menggunakan berbagai alat dan kerangka kerja pengujian seperti Jest, Mocha, dan Jasmine.;JavaScript Testing penting untuk memastikan kualitas dan keamanan kode sebelum dirilis ke produksi."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "8411b49d-d82d-43e0-aa13-9c1e0a82c05a",
      "UserLikeCourse": false,
      "Title": "Browser Object Model dan Document Object Model",
      "Description": "Mempelajari penerapan BOM dan DOM pada halaman website. Selain itu, modul ini mengajarkan teknik pemanipulasian DOM menggunakan JavaScript.",
      "Tag": [
        "Web"
      ],
      "Summary": "Browser Object Model (BOM) adalah objek yang direpresentasikan oleh browser seperti window, history, dan location yang memungkinkan pengembang untuk memanipulasi browser dan halaman web.;Document Object Model (DOM) adalah representasi dari struktur halaman web, yang memungkinkan pengembang untuk memanipulasi elemen HTML dan CSS pada halaman web.;BOM dan DOM adalah fitur penting dalam pengembangan aplikasi web karena memungkinkan pengembang untuk memanipulasi dan mengontrol tampilan dan perilaku halaman web."
    },
    {
      "UserId": "358b9af1-524a-4ac8-92ec-24bb30a43586",
      "CourseId": "40b35cd7-12d5-48c7-86bf-fe83383730b7",
      "UserLikeCourse": false,
      "Title": "Firebase untuk Aplikasi Web",
      "Description": "Belajar menyiapkan Platform as a Service bagi aplikasi front-end sehingga memenuhi setiap kebutuhannya dan meningkatkan pengalaman user dengan performa tinggi.",
      "Tag": [
        "Web"
      ],
      "Summary": "Firebase menyediakan berbagai fitur untuk mempermudah pengembangan aplikasi web, seperti autentikasi, database realtime, hosting, dan lain-lain.;Firebase juga memiliki integrasi dengan Google Cloud Platform, sehingga pengguna dapat memanfaatkan layanan cloud computing yang disediakan oleh Google.;Dengan menggunakan Firebase, pengembang dapat menghemat waktu dan biaya yang dibutuhkan untuk membuat infrastruktur backend sendiri, sehingga lebih fokus pada pengembangan fitur aplikasi."
    }
  ],
  "message": "success"
}

# %%
#@title
# Load JSON data into a Python dictionary
json_string = json.dumps(json_data)
data_dict = json.loads(json_string)

# Extract the list of dictionaries under the 'data' key
data_list = data_dict['data']

# Create a pandas dataframe from the list of dictionaries
df_course = pd.DataFrame(data_list)

# %%
# df_course.to_csv('bytes_submodule_user_like.csv', index=False)

# %% [markdown]
# ## Pre-processing function

# %% [markdown]
# Pre-process data from backend

# %%
def preprocess_data(json_data):
    # Load JSON data into a Python dictionary
    json_string = json.dumps(json_data)
    data_dict = json.loads(json_string)
    # Extract the list of dictionaries under the 'data' key
    data_list = data_dict['data']
    # Create a pandas dataframe from the list of dictionaries
    df_course = pd.DataFrame(data_list)

    # Replace boolean values with integers
    df_course['UserLikeCourse'] = df_course['UserLikeCourse'].replace({False: 0, True: 1})
    df_course['Tag'] = df_course['Tag'].astype(str)
    df_course['Tag'] = df_course['Tag'].str.strip("[]'")
    df_course['UserId'] = df_course['UserId'].astype(str)

    # Load data for collaborative filtering model
    reader = Reader(rating_scale=(0, 1))
    ratings_data = Dataset.load_from_df(df_course[['UserId', 'CourseId', 'UserLikeCourse']], reader)
    trainset = ratings_data.build_full_trainset()
    
    return df_course, reader, ratings_data, trainset

# %% [markdown]
# Pre-process data (Stemming & Stopwords Indonesia)

# %%
nltk.download('punkt') # download tokenizer
# Download Indonesian stop words
nltk.download('stopwords')

# %%
# Create stemmer and stopword remover
stemmer_factory = StemmerFactory()
stemmer = stemmer_factory.create_stemmer()
stopword_factory = StopWordRemoverFactory()
stopwords = stopword_factory.get_stop_words()

# Memoize stopwords and stemmed stopwords
memoized_stopwords = set(stopwords)
memoized_stemmed_stopwords = set(stemmer.stem(stopword) for stopword in memoized_stopwords)

def indo_analyzer(text):
    # Tokenize text
    words = nltk.word_tokenize(text)

    # Remove stop words using memoized set
    words = [word for word in words if word not in memoized_stopwords]

    # Stem words using memoized stemmed stopwords
    stemmed_words = [stemmer.stem(word) for word in words]
    stemmed_words = [word for word in stemmed_words if word not in memoized_stemmed_stopwords]

    return stemmed_words

# %%
#@title
# Replace boolean values with integers
df_course['UserLikeCourse'] = df_course['UserLikeCourse'].replace({False: 0, True: 1})
df_course['Tag'] = df_course['Tag'].astype(str)
df_course['Tag'] = df_course['Tag'].str.strip("[]'")
df_course['UserId'] = df_course['UserId'].astype(str)

# %%
df_course

# %%
# # Load data
# reader = Reader(rating_scale=(0, 1))
# ratings_data = Dataset.load_from_df(df_course[['UserId', 'CourseId', 'UserLikeCourse']], reader)
# trainset = ratings_data.build_full_trainset()

# # Collaborative filtering model
# algo_cf = SVD()
# algo_cf.fit(trainset)

# # Content-based filtering model
# tfidf = TfidfVectorizer(analyzer=indo_analyzer)
# course_features = tfidf.fit_transform(df_course['Title'] + ' ' + df_course['Description'] + ' ' + df_course['Tag'] + ' ' + df_course['Summary'])

def content_based_model(df_course):
    # Content-based filtering model
    tfidf = TfidfVectorizer(analyzer= indo_analyzer)
    course_features = tfidf.fit_transform(df_course['Title'] + ' ' + df_course['Description'] + ' ' + df_course['Tag'] + ' ' + df_course['Summary'])
    return tfidf, course_features

def collaborative_filtering_model(trainset):
    # Define the SVD algorithm
    algo_cf = SVD()
    # Train the algorithm on the training set
    algo_cf.fit(trainset)
    return algo_cf

def content_based_recommendations(df_course, course_index, cosine_similarities, num_recommendations=10):
    sim_scores = list(enumerate(cosine_similarities[course_index]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:num_recommendations+1]
    course_indices = [i[0] for i in sim_scores]
    course_ids = df_course['CourseId'].unique().tolist()
    recommended_course_ids = [(course_ids[i], cosine_similarities[course_index][i]) for i in course_indices if i < len(course_ids)]
    return recommended_course_ids

def hybrid_recommendations(df_course, user_id, algo_cf, cosine_similarities, num_recommendations=10):
    # Get collaborative filtering recommendations
    course_ids = df_course['CourseId'].unique().tolist()
    user_ratings = [1 if df_course.loc[(df_course['UserId'] == user_id) & (df_course['CourseId'] == course_id), 'UserLikeCourse'].empty else df_course.loc[(df_course['UserId'] == user_id) & (df_course['CourseId'] == course_id), 'UserLikeCourse'].iloc[0] for course_id in course_ids]
    user_ratings_dict = dict(zip(course_ids, user_ratings))
    testset = [(user_id, course_id, user_ratings_dict.get(course_id, 0)) for course_id in course_ids]
    predictions = algo_cf.test(testset)
    predictions_dict = dict([(p.iid, p.est) for p in predictions])
    cf_course_indices = [course_ids.index(course_id) for course_id in sorted(predictions_dict, key=predictions_dict.get, reverse=True)]

    # Get content-based filtering recommendations, excluding courses that have already been recommended by collaborative filtering
    excluded_courses = set(cf_course_indices[:num_recommendations])
    content_course_ids = df_course['CourseId'].unique()
    content_course_indices = []
    for course_index in cf_course_indices:
        recommended_course_ids = content_based_recommendations(df_course, course_index, cosine_similarities, num_recommendations=1)
        for course_id, _ in recommended_course_ids:
            if course_id not in excluded_courses and course_id in content_course_ids:
                content_course_indices.append(np.where(content_course_ids == course_id)[0][0])
                excluded_courses.add(course_id)
                if len(content_course_indices) == num_recommendations:
                    break
        if len(content_course_indices) == num_recommendations:
            break

    # Combine recommendations
    hybrid_indices = []
    for i in range(num_recommendations):
        if i < len(cf_course_indices):
            hybrid_indices.append(cf_course_indices[i])
        if i < len(content_course_indices):
            hybrid_indices.append(content_course_indices[i])
    return hybrid_indices[:num_recommendations]

# %%
def get_recommendation(json_data):
    # Preprocess the data
    df_course, reader, ratings_data, trainset = preprocess_data(json_data)

    # Train collaborative filtering model
    algo_cf = collaborative_filtering_model(trainset)

    # Train content-based filtering model
    tfidf, course_features = content_based_model(df_course)

    # Compute cosine similarities
    cosine_similarities = cosine_similarity(course_features, course_features)

    # Get hybrid recommendations for a given user
    user_id = df_course['UserId'][0]
    hybrid_recs = hybrid_recommendations(df_course, user_id, algo_cf, cosine_similarities, num_recommendations=10)

    # Return recommended courses
    result = df_course.loc[hybrid_recs, ['CourseId', 'Title']]
    return result

# %%
get_recommendation(json_data)
